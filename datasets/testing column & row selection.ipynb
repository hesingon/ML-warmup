# %%
import pandas as pd

# %%
df1=pd.read_csv("http://pythonhow.com/wp-content/uploads/2016/01/Income_data.csv")

# %%
print df1
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
help(pd.DataFreame.read_csv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8a3bf658b323> in <module>()
# ----> 1 help(pd.DataFreame.read_csv)
#
# AttributeError: 'module' object has no attribute 'DataFreame'

# %%
df1 #without 'print' in front, it will output a nice table.
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
import numpy
data = numpy.genfromtxt('dataset-har-PUC-Rio-ugulino.csv', delimiter=";", dtype="string")
data
# Out:
# array([['user', 'gender', 'age', ..., 'y4', 'z4', 'class,,'],
#        ['debora', 'Woman', '46', ..., '-103', '-147', 'sitting'],
#        ['debora', 'Woman', '46', ..., '-104', '-145', 'sitting'],
#        ...,
#        ['jose_carlos', 'Man', '75', ..., '-80', '-153', 'walking'],
#        ['jose_carlos', 'Man', '75', ..., '-84', '-156', 'walking'],
#        ['jose_carlos', 'Man', '75', ..., '-88', '-148', 'walking']],
#       dtype='|S18')

# %%
data
# Out:
# array([['user', 'gender', 'age', ..., 'y4', 'z4', 'class,,'],
#        ['debora', 'Woman', '46', ..., '-103', '-147', 'sitting'],
#        ['debora', 'Woman', '46', ..., '-104', '-145', 'sitting'],
#        ...,
#        ['jose_carlos', 'Man', '75', ..., '-80', '-153', 'walking'],
#        ['jose_carlos', 'Man', '75', ..., '-84', '-156', 'walking'],
#        ['jose_carlos', 'Man', '75', ..., '-88', '-148', 'walking']],
#       dtype='|S18')

# %%
data2 = pd.read_csv("./dataset-har-PUC-Rio-ugulino.csv")

# %%
data2
# Out:
#        user;gender;age;how_tall_in_meters;weight;body_mass_index;x1;y1;z1;x2;y2;z2;x3;y3;z3;x4;y4;z4;class  \
# 0                                       debora;Woman;46;1
# 1                                       debora;Woman;46;1
# 2                                       debora;Woman;46;1
# 3                                       debora;Woman;46;1
# 4                                       debora;Woman;46;1
# 5                                       debora;Woman;46;1
# 6                                       debora;Woman;46;1
# 7                                       debora;Woman;46;1
# 8                                       debora;Woman;46;1
# 9                                       debora;Woman;46;1
# 10                                      debora;Woman;46;1
# 11                                      debora;Woman;46;1
# 12                                      debora;Woman;46;1
# 13                                      debora;Woman;46;1
# ...

# %%
data3 = pd.read_csv("./dataset-har-PUC-Rio-ugulino.csv", delimiter=';', header='infer')
data3
# Out:
#                user gender  age how_tall_in_meters  weight body_mass_index  \
# 0            debora  Woman   46               1,62      75            28,6
# 1            debora  Woman   46               1,62      75            28,6
# 2            debora  Woman   46               1,62      75            28,6
# 3            debora  Woman   46               1,62      75            28,6
# 4            debora  Woman   46               1,62      75            28,6
# 5            debora  Woman   46               1,62      75            28,6
# 6            debora  Woman   46               1,62      75            28,6
# 7            debora  Woman   46               1,62      75            28,6
# 8            debora  Woman   46               1,62      75            28,6
# 9            debora  Woman   46               1,62      75            28,6
# 10           debora  Woman   46               1,62      75            28,6
# ...

# %%
data4 = data3.loc[:, 6:14]
data4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-63110682b222> in <module>()
# ----> 1 data4 = data3.loc[:, 6:14]
#       2 data4
#
# /Users/Darius/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /Users/Darius/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     854                 continue
#     855
# --> 856             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     857
#     858         return retval
#
# /Users/Darius/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
# ...

# %%
data4 = data3.loc[:, "x1": "z4"]
data4
# Out:
#         x1   y1   z1  x2   y2   z2   x3   y3   z3   x4   y4   z4
# 0       -3   92  -63 -23   18  -19    5  104  -92 -150 -103 -147
# 1       -3   94  -64 -21   18  -18  -14  104  -90 -149 -104 -145
# 2       -1   97  -61 -12   20  -15  -13  104  -90 -151 -104 -144
# 3       -2   96  -57 -15   21  -16  -13  104  -89 -153 -103 -142
# 4       -1   96  -61 -13   20  -15  -13  104  -89 -153 -104 -143
# 5       -2   95  -62 -14   19  -16  -13  104  -89 -153 -104 -142
# 6        1  100  -62 -10   22  -12  -13  104  -90 -151 -104 -143
# 7       -1   97  -63 -13   20  -15  -12  104  -88 -151 -104 -142
# 8       -1   98  -63 -14   19  -17  -13  104  -90 -152 -103 -144
# 9        0   98  -61 -11   22  -13  -13  104  -90 -151 -104 -144
# 10      -1   95  -60 -13   19  -17  -13  105  -89 -150 -104 -144
# 11       3  100  -59 -10   22  -13  -13  104  -90 -150 -103 -144
# 12       0   96  -61 -14   20  -15  -12  105  -88 -149 -104 -145
# ...
